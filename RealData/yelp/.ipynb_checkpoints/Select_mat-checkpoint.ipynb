# %%
import pickle
import json
from collections import defaultdict as ddict 
from collections import Counter as Cntr
import os.path as osp
import numpy.random as npr
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm_notebook as tqdm

# %matplotlib inline

# %%
root = Path("./rawdataXcode")

# %% [markdown]
# ## Fisrt way
#
# Load all data and extract the submatrix from the whole mat

# %% [markdown]
# #### Num of reviews for each restaurant

# %%
RestDic = ddict(set)
RestCnt = Cntr()

if not osp.isfile(root/"RestDicCnt.pkl"):
    for idx, oneobs in enumerate(open(root/"review.json", "r")):
        print(f"Current index is {idx}")
        oneobs = json.loads(oneobs)
        RestDic[oneobs["business_id"]].add(oneobs["user_id"])
        RestCnt[oneobs["business_id"]]  += 1
        if idx == 1000:
            pass#break
    
    with open(root/"RestDicCnt.pkl", "wb") as f:
        pickle.dump([RestDic, RestCnt], f)

with open(root/"RestDicCnt.pkl", "rb") as f:
    RestDicCnt = pickle.load(f)

RestDic = RestDicCnt[0]
RestCnt = RestDicCnt[1]

# %% [markdown]
# #### Num of reviews for each users

# %%
UserDic = ddict(set)
UserCnt = Cntr()

if not osp.isfile(root/"UserDicCnt.pkl"):
    for idx, oneobs in enumerate(open(root/"review.json", "r")):
        oneobs = json.loads(oneobs)
        UserDic[oneobs["user_id"]].add(oneobs["business_id"])
        UserCnt[oneobs["user_id"]]  += 1

    with open(root/"UserDicCnt.pkl", "wb") as f:
        pickle.dump([UserDic, UserCnt], f)

with open(root/"UserDicCnt.pkl", "rb") as f:
    UserDicCnt = pickle.load(f)

UserDic = UserDicCnt[0]
UserCnt = UserDicCnt[1]

# %% [markdown]
# #### Sort the count w.r.t the number of reviewers and choose restaurants

# %%
m = 1000
n = 1000
sortRCnt = RestCnt.most_common()
allRests = [i[0] for i in sortRCnt]
selRests = allRests[:m]

# %%
selUserCnt = Cntr()
for user, rests in UserDic.items():
    selUserCnt[user] = len(rests.intersection(selRests))

# %%
selUsers = [i[0] for i in selUserCnt.most_common()[:n]]

# %%
# funtion ot extract the Y mat
def size2mat():
    subRests = selRests
    subUsers = selUsers
    n, m = len(subUsers), len(subRests)
    mat = np.zeros((n, m))
    
    for idxn, user in enumerate(subUsers):
        cRests = UserDic[user]
        for idxm, rest in enumerate(subRests):
            if rest in cRests:
                mat[idxn, idxm] = 1
    return mat

# %%
np.mean(size2mat())
# Out:
# 0.058635

# %% [markdown]
# ## Second way
#
# Select a mat by city

# %%
with open(root/"./CityRest.pkl", "rb") as f:
    city = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d2559d118951> in <module>
# ----> 1 with open(root/"./CityRest.pkl", "rb") as f:
#       2     city = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rawdataXcode/CityRest.pkl'

# %%
cityCnt = Cntr()

for key, v in city.items():
    cityCnt[key] = len(v)
    
sortedCityCnt = cityCnt.most_common()
sortedCity = [i[0] for i in sortedCityCnt]

# %%
cCity =sortedCity[0]
cCityRests = city[cCity]

# %%
ccRestCnt = Cntr()
ccUserDic = ddict(set)
ccUserCnt = Cntr()
for ccRest in cCityRests:
    ccRestCnt[ccRest] = RestCnt[ccRest]
    ccUsers = RestDic[ccRest]
    for ccUser in ccUsers:
        ccUserDic[ccUser].add(ccRest)
        ccUserCnt[ccUser] += 1
    
sortRCnt = ccRestCnt.most_common()
ccRests = [i[0] for i in sortRCnt]
sortUCnt = ccUserCnt.most_common()
ccUsers = [i[0] for i in sortUCnt]

# %%
m = 500
n = 1000

cSelRests = ccRests[:m]

# %%
cSelUserCnt = Cntr()
for user, rests in ccUserDic.items():
    cSelUserCnt[user] = len(rests.intersection(cSelRests))

# %%
cSelUsers = [i[0] for i in cSelUserCnt.most_common()[:n]]

# %%
# funtion to extract the Y mat
def citysize2mat():
    subRests = cSelRests
    subUsers = cSelUsers
    n, m = len(subUsers), len(subRests)
    mat = np.zeros((n, m))
    
    for idxn, user in enumerate(subUsers):
        cRests = UserDic[user]
        for idxm, rest in enumerate(subRests):
            if rest in cRests:
                mat[idxn, idxm] = 1
    return mat

# %%
mat = citysize2mat()
np.mean(mat)
# Out:
# 0.09109

# %%
sns.heatmap(mat)

# %% [markdown]
# ### The selected resturant and users are
#
# `cSelRests` and `cSelUsers`

# %% [markdown]
# ### To data

# %%
saveRoot = Path("./JMLR-R1")

# %%
if not osp.isfile(saveRoot/"Y.pkl"):
    Y = ddict(dict)
    for idx, oneobs in enumerate(open(root/"review.json", "r")):
        oneobs = json.loads(oneobs)
        crest = oneobs["business_id"]
        ccust = oneobs["user_id"] 
        if (crest in cSelRests) and (ccust in cSelUsers):
            Y[crest][ccust] = {"stars":oneobs["stars"], "date": oneobs["date"], "UFC":[oneobs["useful"], oneobs["funny"], oneobs["cool"]]}
        if idx == 1000:
            pass #break
    
    with open(saveRoot/"Y.pkl", "wb") as f:
        pickle.dump(Y, f)

with open(saveRoot/"Y.pkl", "rb") as f:
    Y = pickle.load(f)

# %%
if not osp.isfile(saveRoot/"Xrest.pkl"):
    Xrest = {}
    for idx1, oneobs in enumerate(open(root/"business.json", "r")):
        oneobs = json.loads(oneobs)
        crest = oneobs["business_id"]
        if crest in cSelRests:
            Xrest[crest] = oneobs
    with open(saveRoot/"Xrest.pkl", "wb") as f:
        pickle.dump(Xrest, f)

with open(saveRoot/"Xrest.pkl", "rb") as f:
    Xrest = pickle.load(f)

# %%
if not osp.isfile(saveRoot/"Xuser.pkl"):
    Xuser = {}
    for idx2, userobs in enumerate(open(root/"user.json", "r")):
        userobs = json.loads(userobs)
        ccust = userobs["user_id"]
        if ccust in cSelUsers:
            Xuser[ccust] = userobs
    with open(saveRoot/"Xuser.pkl", "wb") as f:
        pickle.dump(Xuser, f)

with open(saveRoot/"Xuser.pkl", "rb") as f:
    Xuser = pickle.load( f)

# %% [markdown]
#  - columns: restuarants, m
#
#  - rows: customers, n
#
#  - covariates:
#    - Reviews: [weekend, Ruseful, Rfunny, Rcool] removed
#    - users: [review_count, yelping_since, num_of_friends, Uuseful, Ufunny, Ucool, fans, num_of_elite, av_stars, c_hot, c_more, c_p, c_cute, c_list, c_note, c_plain, c_cool,  c_funny, c_writer, c_photos]
#    - bussiness: [stars, review_count, is_open, RestTakeOut, BPgarage, BPstreet, BPvalidated, BPlot, BPvalet, hrs_weekdays, hrs_weekend]

# %%
from datetime import datetime
import ast

def date2weekday(datestring):
    date = datetime.strptime(datestring, "%Y-%m-%d")
    weekday = date.weekday()
    if weekday >= 5:
        return 1
    else:
        return 0

def hours2num(hours):
    weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
    weekends = ["Sunday", "Saturday"]
    def int2del(intstring):
        begint, endt  = intstring.split("-")[0], intstring.split("-")[1]
        beginth, begintm = begint.split(":")
        endth, endtm = endt.split(":")
        hrs = float(endth)-float(beginth) + (float(endtm) - float(begintm))/60
        if hrs == 0:
            return 24
        else:
            return hrs
    weekdayhours = np.sum([int2del(hours[weekday]) for weekday in weekdays if weekday in hours.keys()])
    weekendhours = np.sum([int2del(hours[weekend]) for weekend in weekends if weekend in hours.keys()])
    return weekdayhours, weekendhours

# sort the users and restaurants
cSelUsers = sorted(cSelUsers)
cSelRests = sorted(cSelRests)

if not osp.isfile(saveRoot/"Ymat.pkl"):
    Ymat = np.zeros((n, m)) - 1
    for idxcol, restaurant in enumerate(cSelRests):
        datarest = Y[restaurant]
        userkeys = datarest.keys()
        for idxrow, customer in enumerate(cSelUsers):
            if customer in userkeys:
                Ymat[idxrow, idxcol] = datarest[customer]["stars"]
    with open(saveRoot/"Ymat.pkl", "wb") as f:
        pickle.dump(Ymat, f)
with open(saveRoot/"Ymat.pkl", "rb") as f:
    Ymat = pickle.load(f)

# %%
p = 22
if not osp.isfile(saveRoot/"Xmat.pkl"):
    Xmat = np.zeros((n, m, p)) - 1
    for idxcol, restaurant in enumerate(cSelRests):
        cRestDat = Xrest[restaurant]
        for idxrow, customer in enumerate(cSelUsers):
            cCustDat = Xuser[customer]
            Xmat[idxrow, idxcol, 0] = cCustDat["review_count"]
            Xmat[idxrow, idxcol, 1] = len(cCustDat["friends"])
            Xmat[idxrow, idxcol, 2] = cCustDat["useful"]
            Xmat[idxrow, idxcol, 3] = cCustDat["funny"]
            Xmat[idxrow, idxcol, 4] = cCustDat["cool"]
            Xmat[idxrow, idxcol, 5] = cCustDat["fans"]
            Xmat[idxrow, idxcol, 6] = len(cCustDat["elite"])
            Xmat[idxrow, idxcol, 7] = cCustDat["average_stars"]
            Xmat[idxrow, idxcol, 8] = cCustDat["compliment_hot"]
            Xmat[idxrow, idxcol, 9] = cCustDat["compliment_more"]
            Xmat[idxrow, idxcol, 10] = cCustDat["compliment_profile"]
            Xmat[idxrow, idxcol, 11] = cCustDat["compliment_cute"]
            Xmat[idxrow, idxcol, 12] = cCustDat["compliment_list"]
            Xmat[idxrow, idxcol, 13] = cCustDat["compliment_note"]
            Xmat[idxrow, idxcol, 14] = cCustDat["compliment_plain"]
            Xmat[idxrow, idxcol, 15] = cCustDat["compliment_cool"]
            Xmat[idxrow, idxcol, 16] = cCustDat["compliment_funny"]
            Xmat[idxrow, idxcol, 17] = cCustDat["compliment_writer"]
            Xmat[idxrow, idxcol, 18] = cCustDat["compliment_photos"]
            Xmat[idxrow, idxcol, 19] = cRestDat["stars"]
            Xmat[idxrow, idxcol, 20] = cRestDat["review_count"]
            Xmat[idxrow, idxcol, 21] = cRestDat["is_open"]
    with open(saveRoot/"Xmat.pkl", "wb") as f:
        pickle.dump(Xmat, f)

with open(saveRoot/"Xmat.pkl", "rb") as f:
    Xmat = pickle.load(f)

# %%
with open("../JMLR-R1/Xrest.pkl", "rb") as wf:
    data = pickle.load(wf)

# %%
data
# Out:
# {'_pBXtjN43eqMV0XZTz7nmw': {'business_id': '_pBXtjN43eqMV0XZTz7nmw',
#   'name': 'Encore Beach Club at Night',
#   'address': '3131 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.1292433677,
#   'longitude': -115.1656436718,
#   'stars': 3.5,
#   'review_count': 865,
#   'is_open': 0,
#   'attributes': {'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#    'BusinessAcceptsCreditCards': 'True',
#    'Alcohol': "u'full_bar'",
#    'GoodForKids': 'False',
#    'AgesAllowed': "u'21plus'",
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}",
#    'OutdoorSeating': 'True',
#    'HasTV': 'True',
#    'NoiseLevel': "u'very_loud'",
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsPriceRange2': '3',
#    'Music': "{'dj': True, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}",
#    'BikeParking': 'False'},
#   'categories': 'Music Venues, Dance Clubs, Arts & Entertainment, Nightlife',
#   'hours': {'Wednesday': '22:30-4:0',
#    'Friday': '22:30-4:0',
#    'Saturday': '22:30-4:0'}},
#  'ujHiaprwCQ5ewziu0Vi9rw': {'business_id': 'ujHiaprwCQ5ewziu0Vi9rw',
#   'name': 'The Buffet at Bellagio',
#   'address': '3600 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.11322,
#   'longitude': -115.17689,
#   'stars': 3.5,
#   'review_count': 4227,
#   'is_open': 1,
#   'attributes': {'RestaurantsAttire': "'casual'",
#    'RestaurantsDelivery': 'False',
#    'GoodForKids': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'Corkage': 'False',
#    'WheelchairAccessible': 'True',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'RestaurantsPriceRange2': '3',
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsTakeOut': 'False',
#    'RestaurantsReservations': 'False',
#    'NoiseLevel': "u'average'",
#    'WiFi': "'free'",
#    'BikeParking': 'False',
#    'Caters': 'False',
#    'Alcohol': "'full_bar'",
#    'HasTV': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': True, 'breakfast': False}",
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'OutdoorSeating': 'False',
#    'RestaurantsTableService': 'True',
#    'BYOBCorkage': "'yes_free'"},
#   'categories': 'American (New), Buffets, Restaurants',
#   'hours': {'Monday': '7:0-22:0',
#    'Tuesday': '7:0-22:0',
#    'Wednesday': '7:0-22:0',
#    'Thursday': '7:0-22:0',
#    'Friday': '7:0-22:0',
#    'Saturday': '7:0-22:0',
#    'Sunday': '7:0-22:0'}},
#  '_j2EtQtgLuXGRBfbM5YwZA': {'business_id': '_j2EtQtgLuXGRBfbM5YwZA',
#   'name': 'Noodle Asia',
#   'address': '3355 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.122689,
#   'longitude': -115.170163,
#   'stars': 3.5,
#   'review_count': 1090,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsPriceRange2': '2',
#    'RestaurantsTakeOut': 'True',
#    'Alcohol': "u'beer_and_wine'",
#    'RestaurantsAttire': "'casual'",
#    'BikeParking': 'False',
#    'HasTV': 'False',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'BYOBCorkage': "'no'",
#    'OutdoorSeating': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': True, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'WiFi': "'free'",
#    'Caters': 'False',
#    'RestaurantsTableService': 'True',
#    'RestaurantsDelivery': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsReservations': 'False',
#    'GoodForKids': 'True',
#    'WheelchairAccessible': 'True',
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'NoiseLevel': "u'average'"},
#   'categories': 'Restaurants, Asian Fusion, Chinese, Dim Sum, Noodles',
#   'hours': {'Monday': '11:0-3:0',
#    'Tuesday': '11:0-3:0',
#    'Wednesday': '11:0-3:0',
#    'Thursday': '11:0-3:0',
#    'Friday': '11:0-3:0',
#    'Saturday': '11:0-3:0',
#    'Sunday': '11:0-3:0'}},
#  'Wxxvi3LZbHNIDwJ-ZimtnA': {'business_id': 'Wxxvi3LZbHNIDwJ-ZimtnA',
#   'name': 'The Venetian Las Vegas',
#   'address': '3355 South Las Vegas Boulevard',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.121189,
#   'longitude': -115.169657,
#   'stars': 4.0,
#   'review_count': 3499,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'RestaurantsPriceRange2': '3',
#    'RestaurantsDelivery': 'True',
#    'Alcohol': "u'full_bar'",
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#    'RestaurantsTakeOut': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsReservations': 'True',
#    'OutdoorSeating': 'True',
#    'WiFi': "'free'",
#    'GoodForKids': 'False'},
#   'categories': 'Shopping Centers, Resorts, Arts & Entertainment, Hotels, Shopping, Event Planning & Services, Automotive, Restaurants, Hotels & Travel, Casinos, Car Wash',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '0:0-0:0',
#    'Wednesday': '0:0-0:0',
#    'Thursday': '0:0-0:0',
#    'Friday': '0:0-0:0',
#    'Saturday': '0:0-0:0',
#    'Sunday': '0:0-0:0'}},
#  'Vs7gc9EE3k9wARuUcN9piA': {'business_id': 'Vs7gc9EE3k9wARuUcN9piA',
#   'name': 'Pan Asian',
#   'address': '2980 S Durango Dr, Ste 101',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89117',
#   'latitude': 36.1349835,
#   'longitude': -115.2784336,
#   'stars': 4.5,
#   'review_count': 669,
#   'is_open': 1,
#   'attributes': {'RestaurantsPriceRange2': '2',
#    'GoodForKids': 'True',
#    'Alcohol': "u'none'",
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'BusinessAcceptsCreditCards': 'True',
#    'Caters': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'RestaurantsAttire': "u'casual'",
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsTakeOut': 'True',
#    'NoiseLevel': "u'average'",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'BikeParking': 'True',
#    'WiFi': "u'no'",
#    'OutdoorSeating': 'False',
#    'HasTV': 'True',
#    'RestaurantsReservations': 'True',
#    'RestaurantsDelivery': 'False',
#    'RestaurantsTableService': 'True'},
#   'categories': 'Thai, Japanese, Chinese, Restaurants',
#   'hours': {'Monday': '11:0-21:30',
#    'Tuesday': '11:0-21:30',
#    'Wednesday': '11:0-21:30',
#    'Thursday': '11:0-21:30',
#    'Friday': '11:0-21:30',
#    'Saturday': '11:0-21:30'}},
#  'c_iQzwsTDYraPvHSKz88QA': {'business_id': 'c_iQzwsTDYraPvHSKz88QA',
#   'name': 'Sugar Factory',
#   'address': '3655 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.1118765818,
#   'longitude': -115.1725530624,
#   'stars': 3.0,
#   'review_count': 760,
#   'is_open': 0,
#   'attributes': {'Alcohol': "u'full_bar'",
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': True, 'hipster': False, 'divey': False, 'classy': False, 'trendy': True, 'upscale': False, 'casual': True}",
#    'HasTV': 'False',
#    'RestaurantsAttire': "u'casual'",
#    'RestaurantsDelivery': 'False',
#    'GoodForKids': 'True',
#    'RestaurantsPriceRange2': '2',
#    'OutdoorSeating': 'True',
#    'RestaurantsReservations': 'True',
#    'WiFi': "u'no'",
#    'Caters': 'False',
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'NoiseLevel': "u'average'",
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#    'BusinessAcceptsCreditCards': 'True',
#    'BikeParking': 'False'},
#   'categories': 'American (New), Restaurants, Candy Stores, Desserts, Specialty Food, Food',
#   'hours': None},
#  'WRQ-9LluyivReFiQZFUujw': {'business_id': 'WRQ-9LluyivReFiQZFUujw',
#   'name': 'Buldogis Gourmet Hot Dogs',
#   'address': '2291 S Fort Apache Rd, Ste 102',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89117',
#   'latitude': 36.1470835,
#   'longitude': -115.2982993,
#   'stars': 4.5,
#   'review_count': 865,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsBitcoin': 'False',
#    'GoodForKids': 'True',
#    'Alcohol': "u'none'",
#    'RestaurantsDelivery': 'False',
#    'RestaurantsTakeOut': 'True',
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'RestaurantsAttire': "u'casual'",
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'BusinessAcceptsCreditCards': 'True',
#    'HasTV': 'True',
#    'RestaurantsPriceRange2': '1',
#    'RestaurantsGoodForGroups': 'True',
#    'Caters': 'True',
#    'OutdoorSeating': 'True',
#    'WiFi': "u'free'",
#    'RestaurantsReservations': 'False',
#    'BikeParking': 'True',
#    'NoiseLevel': "u'average'"},
#   'categories': 'Korean, Restaurants, Asian Fusion, Chicken Wings, Hot Dogs',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '11:0-19:0',
#    'Wednesday': '11:0-17:0',
#    'Thursday': '11:0-22:0',
#    'Friday': '11:0-23:0',
#    'Saturday': '11:0-23:0'}},
#  'f_eiOrEcMnkHB7GvQVOHkQ': {'business_id': 'f_eiOrEcMnkHB7GvQVOHkQ',
#   'name': 'Terrace Pointe Cafe',
#   'address': '3131 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.126212,
#   'longitude': -115.164514,
#   'stars': 4.0,
#   'review_count': 744,
#   'is_open': 1,
#   'attributes': {'RestaurantsReservations': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'GoodForKids': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'NoiseLevel': "u'average'",
#    'BikeParking': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': True, 'breakfast': True}",
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}",
#    'RestaurantsPriceRange2': '2',
#    'Caters': 'False',
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsDelivery': 'False',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'OutdoorSeating': 'True',
#    'HasTV': 'False',
#    'WiFi': "'free'",
#    'Alcohol': "'full_bar'",
#    'RestaurantsAttire': "'casual'"},
#   'categories': 'American (Traditional), American (New), Restaurants',
#   'hours': {'Monday': '6:0-15:0',
#    'Tuesday': '6:0-15:0',
#    'Wednesday': '6:0-15:0',
#    'Thursday': '6:0-15:0',
#    'Friday': '6:0-15:0',
#    'Saturday': '6:0-15:0',
#    'Sunday': '6:0-15:0'}},
#  'rdE9gg0WB7Z8kRytIMSapg': {'business_id': 'rdE9gg0WB7Z8kRytIMSapg',
#   'name': 'Lazy Dog Restaurant & Bar',
#   'address': '6509 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89119',
#   'latitude': 36.0701464765,
#   'longitude': -115.1738562678,
#   'stars': 4.0,
#   'review_count': 815,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'GoodForKids': 'True',
#    'Smoking': "u'outdoor'",
#    'CoatCheck': 'False',
#    'RestaurantsTakeOut': 'True',
#    'HasTV': 'True',
#    'HappyHour': 'True',
#    'DriveThru': 'False',
#    'RestaurantsDelivery': 'True',
#    'RestaurantsPriceRange2': '2',
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': True, 'upscale': False, 'classy': False, 'casual': True}",
#    'WiFi': "u'free'",
#    'Alcohol': "u'full_bar'",
#    'RestaurantsReservations': 'False',
#    'NoiseLevel': "'average'",
#    'OutdoorSeating': 'True',
#    'Caters': 'True',
#    'RestaurantsTableService': 'True',
#    'GoodForDancing': 'False',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'BestNights': "{'monday': False, 'tuesday': True, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}",
#    'BikeParking': 'True',
#    'RestaurantsAttire': "'casual'",
#    'RestaurantsGoodForGroups': 'True',
#    'WheelchairAccessible': 'True',
#    'Music': "{'dj': False}",
#    'DogsAllowed': 'True',
#    'GoodForMeal': "{'dessert': True, 'latenight': True, 'lunch': True, 'dinner': True, 'brunch': True, 'breakfast': False}"},
#   'categories': 'Comfort Food, American (New), Restaurants, Bars, Breakfast & Brunch, Wine Bars, Tapas/Small Plates, Burgers, Nightlife, Cocktail Bars, Beer, Wine & Spirits, Food, Beer Bar',
#   'hours': {'Monday': '10:0-0:0',
#    'Tuesday': '11:0-0:0',
#    'Wednesday': '11:0-22:0',
#    'Thursday': '11:0-0:0',
#    'Friday': '11:0-0:0',
#    'Saturday': '10:0-0:0',
#    'Sunday': '9:0-0:0'}},
#  'XXW_OFaYQkkGOGniujZFHg': {'business_id': 'XXW_OFaYQkkGOGniujZFHg',
#   'name': 'The Peppermill Restaurant & Fireside Lounge',
#   'address': '2985 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.1336673317,
#   'longitude': -115.1630947555,
#   'stars': 4.0,
#   'review_count': 3260,
#   'is_open': 1,
#   'attributes': {'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'RestaurantsPriceRange2': '2',
#    'RestaurantsReservations': 'False',
#    'NoiseLevel': "u'average'",
#    'RestaurantsDelivery': 'False',
#    'RestaurantsTakeOut': 'True',
#    'Corkage': 'False',
#    'RestaurantsAttire': "'casual'",
#    'OutdoorSeating': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'GoodForKids': 'True',
#    'HappyHour': 'True',
#    'BikeParking': 'True',
#    'HasTV': 'True',
#    'Caters': 'False',
#    'Alcohol': "'full_bar'",
#    'BYOBCorkage': "'no'",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'GoodForDancing': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': True, 'lunch': True, 'dinner': False, 'brunch': True, 'breakfast': True}",
#    'RestaurantsTableService': 'True',
#    'Music': "{'dj': False, 'background_music': True, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}",
#    'RestaurantsGoodForGroups': 'True',
#    'BestNights': "{'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': True}",
#    'WiFi': "'free'",
#    'Smoking': "u'yes'",
#    'CoatCheck': 'False'},
#   'categories': 'Nightlife, Lounges, Restaurants, Bars, American (Traditional), Breakfast & Brunch',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '0:0-0:0',
#    'Wednesday': '0:0-0:0',
#    'Thursday': '0:0-0:0',
#    'Friday': '0:0-0:0',
#    'Saturday': '0:0-0:0',
#    'Sunday': '0:0-0:0'}},
#  'NCFwm2-TDb-oBQ2medmYDg': {'business_id': 'NCFwm2-TDb-oBQ2medmYDg',
#   'name': 'Fountains of Bellagio',
#   'address': '3600 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.112777,
#   'longitude': -115.174006,
#   'stars': 4.5,
#   'review_count': 1200,
#   'is_open': 1,
#   'attributes': {'RestaurantsAttire': "u'casual'",
#    'GoodForKids': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsPriceRange2': '1',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}"},
#   'categories': 'Public Services & Government, Restaurants, Performing Arts, Landmarks & Historical Buildings, Local Flavor, Street Art, Arts & Entertainment',
#   'hours': {'Monday': '15:0-0:0',
#    'Tuesday': '15:0-0:0',
#    'Wednesday': '15:0-0:0',
#    'Thursday': '15:0-0:0',
#    'Friday': '15:0-0:0',
#    'Saturday': '12:0-0:0',
#    'Sunday': '12:0-0:0'}},
#  'a0v7Si0DK4cIko7AQY4YXg': {'business_id': 'a0v7Si0DK4cIko7AQY4YXg',
#   'name': 'Egg Works',
#   'address': '6960 S Rainbow Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89118',
#   'latitude': 36.0621940089,
#   'longitude': -115.2418562125,
#   'stars': 4.5,
#   'review_count': 999,
#   'is_open': 1,
#   'attributes': {'RestaurantsAttire': "u'casual'",
#    'WiFi': "u'free'",
#    'NoiseLevel': "u'average'",
#    'OutdoorSeating': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsTakeOut': 'True',
#    'HasTV': 'True',
#    'GoodForKids': 'True',
#    'RestaurantsReservations': 'False',
#    'Alcohol': "u'full_bar'",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'BusinessAcceptsCreditCards': 'True',
#    'Caters': 'True',
#    'BusinessAcceptsBitcoin': 'False',
#    'BikeParking': 'True',
#    'RestaurantsPriceRange2': '2',
#    'RestaurantsDelivery': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': True, 'breakfast': True}",
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'DriveThru': 'False'},
#   'categories': 'Restaurants, Burgers, Breakfast & Brunch, American (Traditional), Pizza',
#   'hours': {'Monday': '6:0-15:0',
#    'Tuesday': '6:0-15:0',
#    'Wednesday': '6:0-15:0',
#    'Thursday': '6:0-15:0',
#    'Friday': '6:0-15:0',
#    'Saturday': '6:0-15:0',
#    'Sunday': '6:0-15:0'}},
#  'uuGL8diLlHfeUeFuod3F-w': {'business_id': 'uuGL8diLlHfeUeFuod3F-w',
#   'name': "Tom's Urban",
#   'address': '3790 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.102928,
#   'longitude': -115.173847,
#   'stars': 3.5,
#   'review_count': 1671,
#   'is_open': 1,
#   'attributes': {'Music': "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}",
#    'RestaurantsAttire': "'casual'",
#    'Smoking': "u'no'",
#    'HappyHour': 'True',
#    'RestaurantsPriceRange2': '2',
#    'BusinessAcceptsCreditCards': 'True',
#    'Alcohol': "'full_bar'",
#    'RestaurantsTableService': 'True',
#    'BestNights': "{'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': True}",
#    'Ambience': "{'touristy': True, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': True, 'upscale': False, 'classy': False, 'casual': True}",
#    'HasTV': 'True',
#    'WiFi': "'free'",
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsDelivery': 'False',
#    'GoodForDancing': 'False',
#    'Caters': 'False',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#    'OutdoorSeating': 'True',
#    'GoodForKids': 'True',
#    'BikeParking': 'True',
#    'WheelchairAccessible': 'True',
#    'NoiseLevel': "'average'",
#    'CoatCheck': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'GoodForMeal': "{'dessert': True, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': True, 'breakfast': True}",
#    'RestaurantsReservations': 'True'},
#   'categories': 'Gastropubs, Nightlife, Restaurants, American (New), Bars, Sports Bars',
#   'hours': {'Monday': '7:0-2:0',
#    'Tuesday': '7:0-2:0',
#    'Wednesday': '7:0-2:0',
#    'Thursday': '7:0-2:0',
#    'Friday': '7:0-3:0',
#    'Saturday': '7:0-3:0',
#    'Sunday': '7:0-2:0'}},
#  'LYWbyu1EQM2o5hwHG5_Ldg': {'business_id': 'LYWbyu1EQM2o5hwHG5_Ldg',
#   'name': 'RM Seafood',
#   'address': '3950 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89119',
#   'latitude': 36.093063,
#   'longitude': -115.17631,
#   'stars': 3.5,
#   'review_count': 928,
#   'is_open': 0,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsReservations': 'True',
#    'NoiseLevel': "u'average'",
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'RestaurantsAttire': "'casual'",
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': False}",
#    'RestaurantsDelivery': 'False',
#    'OutdoorSeating': 'False',
#    'Caters': 'False',
#    'BYOBCorkage': "'no'",
#    'RestaurantsTakeOut': 'True',
#    'GoodForKids': 'False',
#    'HasTV': 'True',
#    'RestaurantsPriceRange2': '3',
#    'BikeParking': 'False',
#    'WiFi': "u'no'",
#    'Alcohol': "'full_bar'",
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'brunch': False, 'breakfast': False}"},
#   'categories': 'Restaurants, Sushi Bars, Seafood',
#   'hours': {'Monday': '11:30-23:0',
#    'Tuesday': '11:30-23:0',
#    'Wednesday': '11:30-23:0',
#    'Thursday': '11:30-23:0',
#    'Friday': '11:30-23:0',
#    'Saturday': '11:30-23:0',
#    'Sunday': '11:30-23:0'}},
#  'FvVSy2r7_zDEhZWqLgjXNQ': {'business_id': 'FvVSy2r7_zDEhZWqLgjXNQ',
#   'name': 'The Bagel Cafe',
#   'address': '301 N Buffalo Dr',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89145',
#   'latitude': 36.1761018,
#   'longitude': -115.2602821,
#   'stars': 4.0,
#   'review_count': 1005,
#   'is_open': 1,
#   'attributes': {'RestaurantsTakeOut': 'True',
#    'RestaurantsDelivery': 'True',
#    'Caters': 'True',
#    'NoiseLevel': "u'average'",
#    'Alcohol': "u'beer_and_wine'",
#    'BusinessAcceptsBitcoin': 'False',
#    'HasTV': 'True',
#    'GoodForKids': 'True',
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'RestaurantsAttire': "'casual'",
#    'BusinessAcceptsCreditCards': 'True',
#    'DogsAllowed': 'True',
#    'RestaurantsPriceRange2': '2',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'OutdoorSeating': 'False',
#    'RestaurantsReservations': 'False',
#    'BikeParking': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': True, 'breakfast': True}",
#    'WheelchairAccessible': 'True',
#    'WiFi': "u'free'",
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsTableService': 'True'},
#   'categories': 'Breakfast & Brunch, Bagels, Delis, Coffee & Tea, Comfort Food, Cafes, Bakeries, Food, Restaurants',
#   'hours': {'Monday': '6:30-18:0',
#    'Tuesday': '6:30-20:0',
#    'Wednesday': '6:30-17:0',
#    'Thursday': '6:30-20:0',
#    'Friday': '6:30-20:0',
#    'Saturday': '7:0-17:0',
#    'Sunday': '7:0-17:0'}},
#  'OVTZNSkSfbl3gVB9XQIJfw': {'business_id': 'OVTZNSkSfbl3gVB9XQIJfw',
#   'name': 'Cravings Buffet',
#   'address': '3400 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.121237,
#   'longitude': -115.174105,
#   'stars': 3.0,
#   'review_count': 1367,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsPriceRange2': '2',
#    'Corkage': 'False',
#    'RestaurantsAttire': "'casual'",
#    'WiFi': "u'no'",
#    'HasTV': 'False',
#    'GoodForKids': 'True',
#    'Caters': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'NoiseLevel': "u'average'",
#    'RestaurantsDelivery': 'False',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'OutdoorSeating': 'False',
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'Alcohol': "'full_bar'",
#    'BYOBCorkage': "'yes_free'",
#    'RestaurantsReservations': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'BikeParking': 'True',
#    'DogsAllowed': 'False',
#    'RestaurantsTakeOut': 'True'},
#   'categories': 'American (New), Buffets, Restaurants, American (Traditional)',
#   'hours': {'Monday': '7:0-21:0',
#    'Tuesday': '7:0-21:0',
#    'Wednesday': '7:0-21:0',
#    'Thursday': '7:0-21:0',
#    'Friday': '7:0-21:0',
#    'Saturday': '8:0-21:0',
#    'Sunday': '8:0-21:0'}},
#  'Os1n1_idfw9vv9kwULGJnQ': {'business_id': 'Os1n1_idfw9vv9kwULGJnQ',
#   'name': 'Island Style Restaurant',
#   'address': '3909 W Sahara Ave, Ste 1',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89102',
#   'latitude': 36.1440350372,
#   'longitude': -115.1933891745,
#   'stars': 4.5,
#   'review_count': 803,
#   'is_open': 1,
#   'attributes': {'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'Alcohol': "u'none'",
#    'WheelchairAccessible': 'True',
#    'RestaurantsAttire': "'casual'",
#    'BusinessAcceptsBitcoin': 'False',
#    'RestaurantsReservations': 'True',
#    'RestaurantsDelivery': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsTakeOut': 'True',
#    'WiFi': "u'free'",
#    'Caters': 'True',
#    'NoiseLevel': "u'average'",
#    'RestaurantsTableService': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'RestaurantsPriceRange2': '2',
#    'BusinessAcceptsCreditCards': 'True',
#    'OutdoorSeating': 'False',
#    'GoodForKids': 'True',
#    'BikeParking': 'True',
#    'HasTV': 'True'},
#   'categories': 'Restaurants, Japanese, Hawaiian, Korean, Asian Fusion',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '11:0-21:0',
#    'Wednesday': '11:0-21:0',
#    'Thursday': '11:0-21:0',
#    'Friday': '11:0-21:0',
#    'Saturday': '11:0-21:0'}},
#  'rvnTFEq7R2ZHg0_CYbBNFw': {'business_id': 'rvnTFEq7R2ZHg0_CYbBNFw',
#   'name': 'Village Seafood Buffet',
#   'address': 'Rio All-Suite Hotel & Casino, 3700 W. Flamingo Road',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89103',
#   'latitude': 36.118117,
#   'longitude': -115.187298,
#   'stars': 3.5,
#   'review_count': 821,
#   'is_open': 0,
#   'attributes': {'RestaurantsReservations': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsDelivery': 'False',
#    'RestaurantsTakeOut': 'False',
#    'RestaurantsAttire': "'casual'",
#    'BikeParking': 'True',
#    'GoodForKids': 'True',
#    'RestaurantsPriceRange2': '3',
#    'NoiseLevel': "u'average'",
#    'OutdoorSeating': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'BYOBCorkage': "'no'",
#    'Caters': 'False',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'HasTV': 'True',
#    'Alcohol': "'full_bar'",
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'WiFi': "u'free'"},
#   'categories': 'Restaurants, Seafood, Buffets',
#   'hours': {'Monday': '15:30-21:30',
#    'Tuesday': '15:30-21:30',
#    'Wednesday': '15:30-21:30',
#    'Thursday': '15:30-21:30',
#    'Friday': '15:30-21:30',
#    'Saturday': '15:30-21:30',
#    'Sunday': '15:30-21:30'}},
#  'IMLrj2klosTFvPRLv56cng': {'business_id': 'IMLrj2klosTFvPRLv56cng',
#   'name': 'Honey Salt',
#   'address': '1031 S Rampart Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89145',
#   'latitude': 36.160577,
#   'longitude': -115.292996,
#   'stars': 4.0,
#   'review_count': 1517,
#   'is_open': 1,
#   'attributes': {'BikeParking': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'RestaurantsDelivery': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsPriceRange2': '2',
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}",
#    'Alcohol': "u'full_bar'",
#    'NoiseLevel': "u'average'",
#    'Caters': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'GoodForKids': 'True',
#    'RestaurantsTableService': 'True',
#    'RestaurantsReservations': 'True',
#    'WiFi': "'free'",
#    'HasTV': 'True',
#    'OutdoorSeating': 'True',
#    'RestaurantsTakeOut': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': True, 'breakfast': False}"},
#   'categories': 'Cafes, American (New), Restaurants',
#   'hours': {'Monday': '10:30-15:0',
#    'Tuesday': '11:0-21:0',
#    'Wednesday': '11:0-21:0',
#    'Thursday': '11:0-21:0',
#    'Friday': '11:0-22:0',
#    'Saturday': '10:30-22:0',
#    'Sunday': '10:30-21:0'}},
#  '77h11eWv6HKJAgojLx8G4w': {'business_id': '77h11eWv6HKJAgojLx8G4w',
#   'name': 'Eggslut',
#   'address': '3708 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.1099991328,
#   'longitude': -115.1742914289,
#   'stars': 4.0,
#   'review_count': 1826,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'NoiseLevel': "'average'",
#    'RestaurantsGoodForGroups': 'False',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'HasTV': 'False',
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'OutdoorSeating': 'False',
#    'RestaurantsReservations': 'False',
#    'RestaurantsTableService': 'False',
#    'Alcohol': "u'none'",
#    'Caters': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': True, 'breakfast': True}",
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsDelivery': 'False',
#    'RestaurantsAttire': "'casual'",
#    'WiFi': "'no'",
#    'GoodForKids': 'True',
#    'BikeParking': 'False',
#    'RestaurantsPriceRange2': '2'},
#   'categories': 'Sandwiches, Restaurants, Breakfast & Brunch',
#   'hours': {'Monday': '7:0-16:0',
#    'Tuesday': '7:0-16:0',
#    'Wednesday': '7:0-16:0',
#    'Thursday': '7:0-16:0',
#    'Friday': '7:0-19:0',
#    'Saturday': '0:0-19:0',
#    'Sunday': '0:0-16:0'}},
#  'pH0BLkL4cbxKzu471VZnuA': {'business_id': 'pH0BLkL4cbxKzu471VZnuA',
#   'name': 'SUSHISAMBA - Las Vegas',
#   'address': '3327 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.1245818974,
#   'longitude': -115.1675528772,
#   'stars': 4.0,
#   'review_count': 2355,
#   'is_open': 1,
#   'attributes': {'GoodForDancing': 'False',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'GoodForKids': 'False',
#    'Music': "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}",
#    'HasTV': 'True',
#    'Caters': 'False',
#    'RestaurantsPriceRange2': '3',
#    'Alcohol': "'full_bar'",
#    'NoiseLevel': "u'average'",
#    'RestaurantsReservations': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'BikeParking': 'False',
#    'OutdoorSeating': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsDelivery': 'False',
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': True, 'upscale': False, 'casual': False}",
#    'RestaurantsTakeOut': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'RestaurantsAttire': "u'casual'",
#    'BestNights': "{'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': True}",
#    'WiFi': "u'no'"},
#   'categories': 'Bars, Dim Sum, Japanese, Asian Fusion, Restaurants, Chinese, Breakfast & Brunch, Nightlife',
#   'hours': {'Monday': '11:30-1:0',
#    'Tuesday': '11:30-1:0',
#    'Wednesday': '11:30-1:0',
#    'Thursday': '11:30-1:0',
#    'Friday': '11:30-2:0',
#    'Saturday': '11:30-2:0',
#    'Sunday': '11:30-1:0'}},
#  '7EZ4Eu7YJ1ltRCC5jXFJrQ': {'business_id': '7EZ4Eu7YJ1ltRCC5jXFJrQ',
#   'name': 'Corner Market Buffet',
#   'address': '3300 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.124829,
#   'longitude': -115.171991,
#   'stars': 2.5,
#   'review_count': 760,
#   'is_open': 1,
#   'attributes': {'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'Alcohol': "u'full_bar'",
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsPriceRange2': '2',
#    'Caters': 'False',
#    'RestaurantsReservations': 'False',
#    'GoodForKids': 'True',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'NoiseLevel': "u'average'",
#    'BikeParking': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsAttire': "'casual'",
#    'RestaurantsDelivery': 'False',
#    'WiFi': "u'no'",
#    'BYOBCorkage': "'no'",
#    'HasTV': 'False',
#    'RestaurantsTableService': 'True',
#    'OutdoorSeating': 'False',
#    'RestaurantsTakeOut': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}"},
#   'categories': 'Event Planning & Services, Buffets, Asian Fusion, Restaurants, Hotels & Travel, American (Traditional), Sushi Bars, Hotels, Breakfast & Brunch',
#   'hours': {'Monday': '7:0-22:0',
#    'Tuesday': '7:0-22:0',
#    'Wednesday': '7:0-22:0',
#    'Thursday': '7:0-22:0',
#    'Friday': '7:0-22:0',
#    'Saturday': '7:0-22:0',
#    'Sunday': '7:0-22:0'}},
#  'VMXl3Dm1Nwvgwo1PVYTXbg': {'business_id': 'VMXl3Dm1Nwvgwo1PVYTXbg',
#   'name': 'Gold Spike',
#   'address': '217 Las Vegas Blvd N',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89101',
#   'latitude': 36.1713078,
#   'longitude': -115.1402675,
#   'stars': 4.0,
#   'review_count': 684,
#   'is_open': 1,
#   'attributes': {'BestNights': "{'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': True}",
#    'HasTV': 'True',
#    'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}",
#    'Caters': 'False',
#    'Alcohol': "u'full_bar'",
#    'GoodForDancing': 'True',
#    'BikeParking': 'True',
#    'RestaurantsDelivery': 'False',
#    'RestaurantsAttire': "u'casual'",
#    'OutdoorSeating': 'True',
#    'RestaurantsTableService': 'True',
#    'GoodForKids': 'False',
#    'AgesAllowed': "u'21plus'",
#    'RestaurantsGoodForGroups': 'True',
#    'WiFi': "u'free'",
#    'NoiseLevel': "u'average'",
#    'RestaurantsReservations': 'False',
#    'Smoking': "u'outdoor'",
#    'Music': "{'dj': True, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}",
#    'RestaurantsPriceRange2': '2',
#    'HappyHour': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': True, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}",
#    'RestaurantsTakeOut': 'False'},
#   'categories': 'Bars, Nightlife, Lounges, Restaurants, Dance Clubs, Cafes',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '0:0-0:0',
#    'Wednesday': '0:0-0:0',
#    'Thursday': '0:0-0:0',
#    'Friday': '0:0-0:0',
#    'Saturday': '0:0-0:0',
#    'Sunday': '0:0-0:0'}},
#  '6xgcHeLad-VaoTIQewK84A': {'business_id': '6xgcHeLad-VaoTIQewK84A',
#   'name': 'N9NE Steakhouse',
#   'address': '4321 W Flamingo Rd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89103',
#   'latitude': 36.11475,
#   'longitude': -115.1941,
#   'stars': 4.0,
#   'review_count': 838,
#   'is_open': 0,
#   'attributes': {'RestaurantsTakeOut': 'False',
#    'Corkage': 'True',
#    'Caters': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsAttire': "'dressy'",
#    'OutdoorSeating': 'False',
#    'RestaurantsReservations': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsPriceRange2': '4',
#    'BikeParking': 'False',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#    'NoiseLevel': "u'average'",
#    'RestaurantsDelivery': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}",
#    'GoodForKids': 'False',
#    'BYOBCorkage': "'yes_corkage'",
#    'HasTV': 'True',
#    'WiFi': "u'no'",
#    'Alcohol': "'full_bar'"},
#   'categories': 'Seafood, Steakhouses, American (Traditional), Restaurants',
#   'hours': {'Monday': '17:30-22:0',
#    'Tuesday': '17:30-22:0',
#    'Wednesday': '17:30-22:0',
#    'Thursday': '17:30-22:0',
#    'Friday': '17:30-23:0',
#    'Saturday': '17:30-23:0',
#    'Sunday': '17:30-22:0'}},
#  'N6MzDoao6s68nAIW8vS9dQ': {'business_id': 'N6MzDoao6s68nAIW8vS9dQ',
#   'name': "Biaggio's Pizzeria",
#   'address': '4235 S Fort Apache Rd, Ste 160',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89147',
#   'latitude': 36.1122018,
#   'longitude': -115.2980657,
#   'stars': 4.5,
#   'review_count': 695,
#   'is_open': 1,
#   'attributes': {'OutdoorSeating': 'False',
#    'RestaurantsTakeOut': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'RestaurantsReservations': 'True',
#    'NoiseLevel': "u'average'",
#    'RestaurantsGoodForGroups': 'True',
#    'Caters': 'True',
#    'GoodForKids': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'BikeParking': 'True',
#    'HasTV': 'True',
#    'WheelchairAccessible': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'RestaurantsDelivery': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'WiFi': "'free'",
#    'Alcohol': "u'none'",
#    'RestaurantsPriceRange2': '2',
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'RestaurantsTableService': 'True'},
#   'categories': 'Pasta Shops, Pizza, Specialty Food, Italian, Food, Restaurants',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '10:0-21:0',
#    'Wednesday': '10:0-21:0',
#    'Thursday': '10:0-21:0',
#    'Friday': '10:0-22:0',
#    'Saturday': '10:0-22:0',
#    'Sunday': '10:0-21:0'}},
#  'SVGApDPNdpFlEjwRQThCxA': {'business_id': 'SVGApDPNdpFlEjwRQThCxA',
#   'name': "Juan's Flaming Fajitas & Cantina",
#   'address': '9640 W Tropicana, Ste 101',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89147',
#   'latitude': 36.100509,
#   'longitude': -115.302689,
#   'stars': 4.5,
#   'review_count': 1624,
#   'is_open': 1,
#   'attributes': {'RestaurantsGoodForGroups': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'BusinessAcceptsCreditCards': 'True',
#    'OutdoorSeating': 'True',
#    'RestaurantsPriceRange2': '2',
#    'Caters': 'True',
#    'RestaurantsDelivery': 'False',
#    'GoodForKids': 'True',
#    'RestaurantsTakeOut': 'True',
#    'BusinessAcceptsBitcoin': 'False',
#    'Alcohol': "u'full_bar'",
#    'HasTV': 'True',
#    'WiFi': "u'free'",
#    'RestaurantsReservations': 'False',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'NoiseLevel': "u'average'",
#    'BikeParking': 'True',
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'DogsAllowed': 'False'},
#   'categories': 'Nightlife, Restaurants, Bars, Mexican',
#   'hours': {'Monday': '11:0-21:0',
#    'Tuesday': '11:0-21:0',
#    'Wednesday': '11:0-21:0',
#    'Thursday': '11:0-21:0',
#    'Friday': '11:0-22:0',
#    'Saturday': '11:0-22:0',
#    'Sunday': '11:0-21:0'}},
#  'yNVcnSaMSrTmjJBMrHTy9w': {'business_id': 'yNVcnSaMSrTmjJBMrHTy9w',
#   'name': "Battista's Hole In the Wall",
#   'address': '4041 Linq Ln',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.115189,
#   'longitude': -115.168244,
#   'stars': 3.5,
#   'review_count': 1183,
#   'is_open': 1,
#   'attributes': {'Alcohol': "u'full_bar'",
#    'BusinessAcceptsBitcoin': 'False',
#    'WiFi': "u'no'",
#    'RestaurantsDelivery': 'False',
#    'BYOBCorkage': "'yes_free'",
#    'BusinessAcceptsCreditCards': 'True',
#    'BestNights': "{'monday': False, 'tuesday': False, 'friday': True, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': True}",
#    'Corkage': 'False',
#    'NoiseLevel': "u'average'",
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'RestaurantsReservations': 'True',
#    'RestaurantsAttire': "'casual'",
#    'BikeParking': 'True',
#    'RestaurantsTakeOut': 'False',
#    'Caters': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsPriceRange2': '2',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'Smoking': "u'no'",
#    'GoodForDancing': 'False',
#    'OutdoorSeating': 'False',
#    'GoodForKids': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'HasTV': 'True',
#    'Music': "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}"},
#   'categories': 'Bars, Restaurants, Nightlife, Italian, Wine Bars',
#   'hours': {'Monday': '17:0-22:15',
#    'Tuesday': '17:0-22:15',
#    'Wednesday': '17:0-22:15',
#    'Thursday': '17:0-22:15',
#    'Friday': '17:0-22:45',
#    'Saturday': '17:0-22:45',
#    'Sunday': '17:0-22:15'}},
#  'TTDMJetAQKfxVzKZy4Z_2Q': {'business_id': 'TTDMJetAQKfxVzKZy4Z_2Q',
#   'name': 'Allegiant Air',
#   'address': '5757 Wayne Newton Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89119',
#   'latitude': 36.08572,
#   'longitude': -115.153224,
#   'stars': 1.5,
#   'review_count': 778,
#   'is_open': 1,
#   'attributes': {'WiFi': "u'no'"},
#   'categories': 'Airlines, Hotels & Travel, Airports, Travel Services, Transportation',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '0:0-0:0',
#    'Wednesday': '0:0-0:0',
#    'Thursday': '0:0-0:0',
#    'Friday': '0:0-0:0',
#    'Saturday': '0:0-0:0',
#    'Sunday': '0:0-0:0'}},
#  'g8oxQ1Ji9mr9PMjhEfaWSg': {'business_id': 'g8oxQ1Ji9mr9PMjhEfaWSg',
#   'name': "Dick's Last Resort",
#   'address': '3850 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.0994443035,
#   'longitude': -115.1754684871,
#   'stars': 3.0,
#   'review_count': 853,
#   'is_open': 1,
#   'attributes': {'RestaurantsGoodForGroups': 'True',
#    'Alcohol': "u'full_bar'",
#    'HasTV': 'True',
#    'RestaurantsAttire': "'casual'",
#    'RestaurantsPriceRange2': '2',
#    'BikeParking': 'False',
#    'RestaurantsReservations': 'True',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'HappyHour': 'True',
#    'Caters': 'True',
#    'RestaurantsDelivery': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsTakeOut': 'True',
#    'GoodForKids': 'True',
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'NoiseLevel': "'average'",
#    'BestNights': "{'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': True}",
#    'Music': "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}",
#    'Smoking': "u'no'",
#    'GoodForDancing': 'False',
#    'WiFi': "u'no'",
#    'OutdoorSeating': 'True'},
#   'categories': 'American (New), Food, Bars, American (Traditional), Restaurants, Nightlife, Beer, Wine & Spirits',
#   'hours': {'Monday': '11:0-23:0',
#    'Tuesday': '11:0-23:0',
#    'Wednesday': '11:0-23:0',
#    'Thursday': '11:0-23:0',
#    'Friday': '11:0-0:0',
#    'Saturday': '11:0-0:0',
#    'Sunday': '11:0-23:0'}},
#  'sOYsxYYFl03PhHmz_rBDZQ': {'business_id': 'sOYsxYYFl03PhHmz_rBDZQ',
#   'name': 'The Sparklings',
#   'address': '8310 S Rainbow Blvd, Ste 100',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89139',
#   'latitude': 36.0373841989,
#   'longitude': -115.242948945,
#   'stars': 4.0,
#   'review_count': 829,
#   'is_open': 1,
#   'attributes': {'Caters': 'False',
#    'GoodForKids': 'True',
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': True, 'trendy': False, 'upscale': False, 'classy': False, 'casual': False}",
#    'OutdoorSeating': 'True',
#    'WheelchairAccessible': 'True',
#    'RestaurantsReservations': 'True',
#    'NoiseLevel': "'average'",
#    'BikeParking': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'BusinessAcceptsBitcoin': 'False',
#    'RestaurantsAttire': "u'casual'",
#    'RestaurantsPriceRange2': '2',
#    'RestaurantsTakeOut': 'True',
#    'HasTV': 'True',
#    'DogsAllowed': 'False',
#    'RestaurantsDelivery': 'False',
#    'Alcohol': "u'full_bar'",
#    'WiFi': "u'free'",
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsTableService': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'GoodForMeal': "{'dessert': True, 'latenight': True, 'lunch': False, 'dinner': True, 'brunch': False, 'breakfast': False}"},
#   'categories': 'Restaurants, American (New)',
#   'hours': {'Monday': '11:0-2:0',
#    'Tuesday': '11:0-2:0',
#    'Wednesday': '11:0-2:0',
#    'Thursday': '11:0-2:0',
#    'Friday': '11:0-3:0',
#    'Saturday': '11:0-3:0',
#    'Sunday': '10:0-2:0'}},
#  'n8Zqqhff-2cxzWt_nwhU2Q': {'business_id': 'n8Zqqhff-2cxzWt_nwhU2Q',
#   'name': 'Public School 702',
#   'address': '1850 Festival Plaza Dr',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89135',
#   'latitude': 36.151269,
#   'longitude': -115.332772,
#   'stars': 4.0,
#   'review_count': 1167,
#   'is_open': 1,
#   'attributes': {'Caters': 'False',
#    'NoiseLevel': "'average'",
#    'RestaurantsTableService': 'True',
#    'BestNights': "{'monday': True, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}",
#    'RestaurantsTakeOut': 'True',
#    'Alcohol': "'full_bar'",
#    'RestaurantsGoodForGroups': 'True',
#    'HappyHour': 'True',
#    'RestaurantsReservations': 'True',
#    'GoodForDancing': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'BikeParking': 'True',
#    'WheelchairAccessible': 'True',
#    'CoatCheck': 'False',
#    'HasTV': 'True',
#    'WiFi': "'free'",
#    'OutdoorSeating': 'True',
#    'GoodForKids': 'True',
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'BusinessParking': "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': True}",
#    'RestaurantsAttire': "'casual'",
#    'Smoking': "u'no'",
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': True, 'breakfast': False}",
#    'DogsAllowed': 'False',
#    'RestaurantsPriceRange2': '2',
#    'Music': "{'dj': False}",
# ...
#    'Thursday': '0:0-22:30',
#    'Friday': '10:0-2:0',
#    'Saturday': '10:0-2:0',
#    'Sunday': '10:0-22:0'}},
#  '4qG3Gh8QyugC1XvoTlmgcQ': {'business_id': '4qG3Gh8QyugC1XvoTlmgcQ',
#   'name': 'Egg Works',
#   'address': '9355 W Flamingo Rd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89147',
#   'latitude': 36.1145171608,
#   'longitude': -115.2955863655,
#   'stars': 4.5,
#   'review_count': 732,
#   'is_open': 1,
#   'attributes': {'Corkage': 'False',
#    'Alcohol': "u'full_bar'",
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsPriceRange2': '2',
#    'RestaurantsReservations': 'False',
#    'GoodForKids': 'True',
#    'Caters': 'True',
#    'BYOBCorkage': "'yes_free'",
#    'OutdoorSeating': 'False',
#    'BikeParking': 'True',
#    'RestaurantsDelivery': 'False',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'BusinessAcceptsBitcoin': 'False',
#    'RestaurantsAttire': "'casual'",
#    'HasTV': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': True, 'breakfast': True}",
#    'RestaurantsGoodForGroups': 'True',
#    'WiFi': "'free'",
#    'NoiseLevel': "u'average'"},
#   'categories': 'Restaurants, Brasseries, Burgers, Breakfast & Brunch, American (Traditional)',
#   'hours': {'Monday': '6:0-15:0',
#    'Tuesday': '6:0-15:0',
#    'Wednesday': '6:0-15:0',
#    'Thursday': '6:0-15:0',
#    'Friday': '6:0-15:0',
#    'Saturday': '6:0-15:0',
#    'Sunday': '6:0-15:0'}},
#  'oXoVJ0xKv82cBo9U6oEjlQ': {'business_id': 'oXoVJ0xKv82cBo9U6oEjlQ',
#   'name': 'Chayo Mexican Kitchen + Tequila Bar',
#   'address': '3545 S Las Vegas Blvd',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.117735,
#   'longitude': -115.171714,
#   'stars': 3.5,
#   'review_count': 1487,
#   'is_open': 1,
#   'attributes': {'BikeParking': 'False',
#    'WiFi': "u'free'",
#    'RestaurantsPriceRange2': '2',
#    'BestNights': "{'monday': False, 'tuesday': True, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}",
#    'RestaurantsAttire': "u'casual'",
#    'Smoking': "u'no'",
#    'GoodForKids': 'False',
#    'RestaurantsTakeOut': 'True',
#    'CoatCheck': 'False',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': True, 'lot': False, 'valet': True}",
#    'HasTV': 'True',
#    'OutdoorSeating': 'True',
#    'WheelchairAccessible': 'True',
#    'Music': "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}",
#    'HappyHour': 'True',
#    'Caters': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'Alcohol': "u'full_bar'",
#    'NoiseLevel': "u'average'",
#    'RestaurantsGoodForGroups': 'True',
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'GoodForDancing': 'False',
#    'RestaurantsDelivery': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'BusinessAcceptsBitcoin': 'False',
#    'RestaurantsTableService': 'True',
#    'RestaurantsReservations': 'True'},
#   'categories': 'Nightlife, Breakfast & Brunch, Restaurants, Mexican, Bars, Local Flavor',
#   'hours': {'Monday': '8:0-0:0',
#    'Tuesday': '8:0-0:0',
#    'Wednesday': '8:0-0:0',
#    'Thursday': '8:0-0:0',
#    'Friday': '8:0-2:0',
#    'Saturday': '8:0-2:0',
#    'Sunday': '8:0-0:0'}},
#  'rbcfYmJtqwIkk17IeOI5Kw': {'business_id': 'rbcfYmJtqwIkk17IeOI5Kw',
#   'name': 'BARDOT Brasserie',
#   'address': '3730 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.1072817167,
#   'longitude': -115.1765477628,
#   'stars': 4.0,
#   'review_count': 932,
#   'is_open': 1,
#   'attributes': {'RestaurantsReservations': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsPriceRange2': '3',
#    'OutdoorSeating': 'False',
#    'RestaurantsTakeOut': 'False',
#    'NoiseLevel': "u'average'",
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'RestaurantsAttire': "'dressy'",
#    'WiFi': "u'no'",
#    'GoodForKids': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'WheelchairAccessible': 'True',
#    'RestaurantsTableService': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'brunch': True, 'breakfast': False}",
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': True, 'classy': True, 'casual': False}",
#    'HasTV': 'True',
#    'Alcohol': "u'full_bar'",
#    'Caters': 'False',
#    'RestaurantsDelivery': 'False',
#    'BikeParking': 'False'},
#   'categories': 'French, Restaurants, Hostels, Hotels & Travel, Steakhouses, Brasseries, Cafes',
#   'hours': {'Monday': '11:0-22:30',
#    'Tuesday': '11:0-22:30',
#    'Wednesday': '11:0-22:30',
#    'Thursday': '11:0-22:30',
#    'Friday': '11:0-22:30',
#    'Saturday': '9:30-22:30',
#    'Sunday': '9:30-22:30'}},
#  'UV2Jt8slktGu14gLZeNCjA': {'business_id': 'UV2Jt8slktGu14gLZeNCjA',
#   'name': 'Mint Indian Bistro',
#   'address': '730 E Flamingo Rd, Ste 10',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89119',
#   'latitude': 36.115118,
#   'longitude': -115.1477724,
#   'stars': 4.0,
#   'review_count': 1071,
#   'is_open': 1,
#   'attributes': {'BikeParking': 'True',
#    'Caters': 'True',
#    'RestaurantsDelivery': 'False',
#    'OutdoorSeating': 'True',
#    'NoiseLevel': "u'average'",
#    'Alcohol': "u'full_bar'",
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'WiFi': "u'no'",
#    'RestaurantsAttire': "'casual'",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'BYOBCorkage': "'no'",
#    'RestaurantsPriceRange2': '2',
#    'BusinessAcceptsCreditCards': 'True',
#    'GoodForKids': 'True',
#    'HasTV': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsReservations': 'True',
#    'RestaurantsTakeOut': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}"},
#   'categories': 'Pakistani, Halal, Vegetarian, Himalayan/Nepalese, Vegan, Indian, Restaurants',
#   'hours': {'Monday': '11:0-23:30',
#    'Tuesday': '11:0-23:30',
#    'Wednesday': '11:0-23:30',
#    'Thursday': '11:0-23:30',
#    'Friday': '11:0-23:30',
#    'Saturday': '11:0-23:30',
#    'Sunday': '11:0-23:30'}},
#  'ybHlmdUHLPKfv85bRK4Wtw': {'business_id': 'ybHlmdUHLPKfv85bRK4Wtw',
#   'name': "Grouchy John's Coffee",
#   'address': '8520 S Maryland Pkwy, Ste 100',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89123',
#   'latitude': 36.0350856,
#   'longitude': -115.1357861,
#   'stars': 4.5,
#   'review_count': 1076,
#   'is_open': 1,
#   'attributes': {'WiFi': "u'free'",
#    'RestaurantsPriceRange2': '1',
#    'RestaurantsTableService': 'False',
#    'RestaurantsAttire': "u'casual'",
#    'HasTV': 'True',
#    'GoodForKids': 'True',
#    'RestaurantsTakeOut': 'True',
#    'BusinessAcceptsBitcoin': 'False',
#    'BikeParking': 'True',
#    'OutdoorSeating': 'True',
#    'Caters': 'True',
#    'RestaurantsDelivery': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'ByAppointmentOnly': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'Alcohol': "u'none'",
#    'Ambience': "{'touristy': False, 'hipster': True, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': True, 'upscale': False, 'classy': False, 'casual': True}",
#    'RestaurantsReservations': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': True}",
#    'NoiseLevel': "u'average'"},
#   'categories': 'Food Trucks, Breakfast & Brunch, Cafes, Food, Bagels, Juice Bars & Smoothies, Restaurants, Coffee & Tea',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '5:0-21:0',
#    'Wednesday': '5:0-21:0',
#    'Thursday': '5:0-21:0',
#    'Friday': '5:0-21:0',
#    'Saturday': '5:0-21:0',
#    'Sunday': '5:0-21:0'}},
#  'RCdWzJI0acxponN70QDRcw': {'business_id': 'RCdWzJI0acxponN70QDRcw',
#   'name': 'Delano Las Vegas',
#   'address': '3940 Las Vegas Blvd S',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89119',
#   'latitude': 36.090182,
#   'longitude': -115.176807,
#   'stars': 3.5,
#   'review_count': 632,
#   'is_open': 1,
#   'attributes': {'WiFi': "'free'",
#    'RestaurantsPriceRange2': '3',
#    'BusinessAcceptsCreditCards': 'True',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}"},
#   'categories': 'Hotels & Travel, Event Planning & Services, Hotels',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '0:0-0:0',
#    'Wednesday': '0:0-0:0',
#    'Thursday': '0:0-0:0',
#    'Friday': '0:0-0:0',
#    'Saturday': '0:0-0:0',
#    'Sunday': '0:0-0:0'}},
#  '3kdSl5mo9dWC4clrQjEDGg': {'business_id': '3kdSl5mo9dWC4clrQjEDGg',
#   'name': 'Egg & I',
#   'address': '4533 W Sahara Ave, Ste 5',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89102',
#   'latitude': 36.1440852,
#   'longitude': -115.2024865,
#   'stars': 4.5,
#   'review_count': 3300,
#   'is_open': 1,
#   'attributes': {'OutdoorSeating': 'True',
#    'RestaurantsAttire': "'casual'",
#    'HasTV': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'GoodForKids': 'True',
#    'RestaurantsPriceRange2': '2',
#    'Alcohol': "u'full_bar'",
#    'RestaurantsReservations': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'Corkage': 'False',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'BYOBCorkage': "'yes_free'",
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'Caters': 'True',
#    'BusinessAcceptsBitcoin': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': True, 'breakfast': True}",
#    'WiFi': "u'free'",
#    'NoiseLevel': "u'average'",
#    'BikeParking': 'True',
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsDelivery': 'False'},
#   'categories': 'Breakfast & Brunch, Sandwiches, Burgers, Restaurants, American (Traditional), Pizza',
#   'hours': {'Monday': '8:0-15:0',
#    'Tuesday': '6:0-15:0',
#    'Wednesday': '6:0-15:0',
#    'Thursday': '6:0-15:0',
#    'Friday': '6:0-15:0',
#    'Saturday': '6:0-15:0',
#    'Sunday': '6:0-15:0'}},
#  'fHM09_y3QX3n4a_bIFbk_w': {'business_id': 'fHM09_y3QX3n4a_bIFbk_w',
#   'name': 'Grand Lux Cafe',
#   'address': '3327 Las Vegas Blvd S, Ste 1580',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.1218602707,
#   'longitude': -115.1689448836,
#   'stars': 4.0,
#   'review_count': 1193,
#   'is_open': 1,
#   'attributes': {'RestaurantsTakeOut': 'True',
#    'BikeParking': 'False',
#    'RestaurantsDelivery': 'False',
#    'Alcohol': "u'full_bar'",
#    'Caters': 'False',
#    'NoiseLevel': "u'average'",
#    'RestaurantsReservations': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'RestaurantsTableService': 'True',
#    'GoodForKids': 'True',
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'RestaurantsPriceRange2': '2',
#    'HasTV': 'True',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'WiFi': "'free'",
#    'RestaurantsGoodForGroups': 'True',
#    'OutdoorSeating': 'False',
#    'ByAppointmentOnly': 'False',
#    'GoodForMeal': "{'dessert': True, 'latenight': True, 'lunch': True, 'dinner': True, 'brunch': True, 'breakfast': True}"},
#   'categories': 'Restaurants, American (New), Food, American (Traditional), Desserts, Barbeque, Seafood',
#   'hours': {'Monday': '6:0-2:0',
#    'Tuesday': '6:0-2:0',
#    'Wednesday': '6:0-2:0',
#    'Thursday': '6:0-2:0',
#    'Friday': '6:0-3:0',
#    'Saturday': '6:0-3:0',
#    'Sunday': '6:0-2:0'}},
#  '1DP5vHxJzCDbgawv0WC3yA': {'business_id': '1DP5vHxJzCDbgawv0WC3yA',
#   'name': 'Rose. Rabbit. Lie',
#   'address': '3708 Las Vegas Blvd S, Level 2, The Chelsea Tower, The Chelsea Tower',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89109',
#   'latitude': 36.109759,
#   'longitude': -115.176655,
#   'stars': 4.0,
#   'review_count': 908,
#   'is_open': 1,
#   'attributes': {'HappyHour': 'True',
#    'RestaurantsTakeOut': 'False',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#    'Smoking': "u'no'",
#    'WheelchairAccessible': 'True',
#    'HasTV': 'False',
#    'RestaurantsAttire': "u'dressy'",
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}",
#    'BusinessAcceptsCreditCards': 'True',
#    'OutdoorSeating': 'False',
#    'Alcohol': "u'full_bar'",
#    'CoatCheck': 'True',
#    'GoodForKids': 'False',
#    'Music': "{'dj': False, 'background_music': False, 'jukebox': False, 'live': True, 'video': False, 'karaoke': False}",
#    'BikeParking': 'False',
#    'NoiseLevel': "u'loud'",
#    'RestaurantsReservations': 'True',
#    'RestaurantsPriceRange2': '4',
#    'RestaurantsTableService': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': True, 'lunch': False, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'BestNights': "{'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': True}",
#    'Caters': 'False',
#    'WiFi': "u'no'",
#    'RestaurantsDelivery': 'False',
#    'GoodForDancing': 'False'},
#   'categories': 'Diners, Nightlife, Restaurants, Bars, Social Clubs, American (New), Performing Arts, Cocktail Bars, Arts & Entertainment',
#   'hours': {'Wednesday': '18:0-0:0',
#    'Thursday': '18:0-0:0',
#    'Friday': '18:0-0:0',
#    'Saturday': '18:0-0:0',
#    'Sunday': '18:0-0:0'}},
#  'p5rpYtxS5xPQjt3MXYVEwA': {'business_id': 'p5rpYtxS5xPQjt3MXYVEwA',
#   'name': 'Greens and Proteins',
#   'address': '8975 S Eastern Ave, Ste 3C',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postal_code': '89123',
#   'latitude': 36.026212,
#   'longitude': -115.1193405,
#   'stars': 4.0,
#   'review_count': 704,
#   'is_open': 1,
#   'attributes': {'Alcohol': "u'none'",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'Caters': 'True',
#    'HasTV': 'True',
#    'NoiseLevel': "u'average'",
#    'WiFi': "u'free'",
#    'BikeParking': 'True',
#    'GoodForKids': 'True',
#    'RestaurantsDelivery': 'False',
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': True}",
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsReservations': 'False',
#    'RestaurantsAttire': "u'casual'",
#    'OutdoorSeating': 'True',
#    'RestaurantsPriceRange2': '2',
#    'BusinessAcceptsCreditCards': 'True'},
#   'categories': 'Sandwiches, Cafes, Pizza, Vegetarian, Gluten-Free, American (Traditional), Restaurants, Breakfast & Brunch, Burgers, Vegan, Food, Juice Bars & Smoothies, American (New)',
#   'hours': {'Monday': '9:30-19:30',
#    'Tuesday': '7:0-22:0',
#    'Wednesday': '7:0-22:0',
#    'Thursday': '7:0-22:0',
#    'Friday': '7:0-22:0',
#    'Saturday': '7:0-22:0',
#    'Sunday': '7:30-14:30'}}}
